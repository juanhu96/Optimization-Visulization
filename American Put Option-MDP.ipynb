# %% [markdown]
# ## Example: American Put Option

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ### Initialize Parameters

# %%
# Total day
N = 15
# Initial price
init_price = 50
# Strike Price
strike_price = 48
# Chance of going up
chance_up = 0.6
# Chance of going down
chance_down = 0.4 
# Percentage of going up
percentage_up = 0.01
# Percentage of going down
percentage_down = 0.01

# %% [markdown]
# ### Initialize Tables

# %%
# Initialize value function and policy tables
# which are both (2N-1) * N matrix
stock_price_table = [[0 for d in range(N)] for d in range(2*N-1)]
value_function_table = [[0 for d in range(N)] for d in range(2*N-1)]
policy_table = [["" for d in range(N)] for d in range(2*N-1)]


# Initialize the stock price table
def intialize_table():
        for price in range(2 * N - 1):
            if price < N - 1:
                for period in range(N - 1 - price, N):
                    stock_price_table[price][period] = init_price * ((1 + percentage_up)**(N-1-price))
#                 for period in range(price+1):
#                     stock_price_table[price][N - 1 - period] = init_price * ((1 + percentage_up)**(N-1-price))
            
            if price == N - 1:
                for period in range(price + 1):
                    stock_price_table[price][period] = init_price
            
            if price > N - 1:
                for period in range(price - N + 1, N):
                    stock_price_table[price][period] = init_price * ((1 - percentage_down)**(price-N+1))
#                 for period in range(2*N-1 - price):
#                     stock_price_table[price][N - 1 - period] = init_price * ((1 - percentage_down)**(price-N+1))
        return

    
def value_iteration():
    # Initialize the last column first (at period = N - 1)
    for price in range(2*N-1):
            exercise = strike_price - stock_price_table[price][N-1]
            wait = 0
            value_function_table[price][N-1] = max(wait, exercise)
            if(wait > exercise):
                policy_table[price][N-1] = "wait"
            else:
                policy_table[price][N-1] = "exercise"
    
    # Initialize the rest by backward induction
    for period in range(N - 2,-1,-1):
        for price in range(N - period - 1, N + period):
            exercise = strike_price - stock_price_table[price][period]
            wait = chance_up * value_function_table[price - 1][period + 1] + chance_down * value_function_table[price + 1][period + 1]
            value_function_table[price][period] = max(wait, exercise)
            if(wait > exercise):
                policy_table[price][period] = "wait"
            else:
                policy_table[price][period] = "exercise"
            
    return

intialize_table()
value_iteration()

# %%
col_name = map(str, range(1, N+1))
rows = list(np.array(np.matrix(stock_price_table)[:,N-1]).reshape(-1,))
round_rows = list(np.around(np.array(rows),2))

# %% [markdown]
# ### Value Function Table

# %%
value = pd.DataFrame(np.matrix(value_function_table))
value.columns = col_name
value.columns.name = 'Price/Period'
value.index = round_rows

value.to_csv("value_table.csv", sep=';') 

def color_negative_red1(val):
    color = 'red' if val > 0 else 'black'
    return 'color: %s' % color
value = value.style.applymap(color_negative_red1)
value
# Out:
# <style  type="text/css" >
#     #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col0 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col1 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col2 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col3 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col4 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col5 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col6 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col7 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col8 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col9 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col10 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col11 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col12 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col13 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow0_col14 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col0 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col1 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col2 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col3 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col4 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col5 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col6 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col7 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col8 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col9 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col10 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col11 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col12 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col13 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow1_col14 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col0 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col1 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col2 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col3 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col4 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col5 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col6 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col7 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col8 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col9 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col10 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col11 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col12 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col13 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow2_col14 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col0 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col1 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col2 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col3 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col4 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col5 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col6 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col7 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col8 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col9 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col10 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col11 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col12 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col13 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow3_col14 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col0 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col1 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col2 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col3 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col4 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col5 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col6 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col7 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col8 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col9 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col10 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col11 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col12 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col13 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow4_col14 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col0 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col1 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col2 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col3 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col4 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col5 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col6 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col7 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col8 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col9 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col10 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292_acbc3283927frow5_col11 {
#             color:  black;
#         }    #T_321473b4_ebb3_11e8_9292

# %% [markdown]
# ### Policy Table

# %%
policy = pd.DataFrame(np.matrix(policy_table))
col_name = map(str, range(1, N+1))
policy.columns = col_name
policy.index = round_rows
policy.columns.name = 'Price/Period'
policy.to_csv("policy_table.csv", sep=';') 
policy
# Out:
# Price/Period     1     2     3     4     5     6         7         8  \
# 57.47
# 56.90
# 56.34
# 55.78
# 55.23
# 54.68
# 54.14
# 53.61                                                           wait
# 53.08                                                 wait      wait
# 52.55                                       wait      wait      wait
# 52.03                                 wait  wait      wait      wait
# 51.52                           wait  wait  wait      wait      wait
# 51.00                     wait  wait  wait  wait      wait      wait
# 50.50               wait  wait  wait  wait  wait      wait      wait
# 50.00         wait  wait  wait  wait  wait  wait      wait      wait
# 49.50               wait  wait  wait  wait  wait      wait      wait
# 49.00                     wait  wait  wait  wait      wait      wait
# 48.51                           wait  wait  wait      wait      wait
# 48.03                                 wait  wait      wait      wait
# 47.55                                       wait      wait      wait
# 47.07                                             exercise  exercise
# 46.60                                                       exercise
# 46.14
# 45.68
# 45.22
# 44.77
# 44.32
# 43.88
# 43.44
#
# Price/Period         9        10        11        12        13        14  \
# 57.47
# 56.90                                                               wait
# 56.34                                                     wait      wait
# 55.78                                           wait      wait      wait
# 55.23                                 wait      wait      wait      wait
# 54.68                       wait      wait      wait      wait      wait
# 54.14             wait      wait      wait      wait      wait      wait
# 53.61             wait      wait      wait      wait      wait      wait
# 53.08             wait      wait      wait      wait      wait      wait
# 52.55             wait      wait      wait      wait      wait      wait
# 52.03             wait      wait      wait      wait      wait      wait
# 51.52             wait      wait      wait      wait      wait      wait
# 51.00             wait      wait      wait      wait      wait      wait
# 50.50             wait      wait      wait      wait      wait      wait
# 50.00             wait      wait      wait      wait      wait      wait
# 49.50             wait      wait      wait      wait      wait      wait
# 49.00             wait      wait      wait      wait      wait      wait
# 48.51             wait      wait      wait      wait      wait      wait
# 48.03             wait      wait      wait      wait      wait      wait
# 47.55             wait      wait      wait      wait      wait  exercise
# 47.07         exercise  exercise  exercise  exercise  exercise  exercise
# 46.60         exercise  exercise  exercise  exercise  exercise  exercise
# 46.14         exercise  exercise  exercise  exercise  exercise  exercise
# 45.68                   exercise  exercise  exercise  exercise  exercise
# 45.22                             exercise  exercise  exercise  exercise
# 44.77                                       exercise  exercise  exercise
# 44.32                                                 exercise  exercise
# 43.88                                                           exercise
# 43.44
#
# Price/Period        15
# 57.47             wait
# 56.90             wait
# 56.34             wait
# 55.78             wait
# 55.23             wait
# 54.68             wait
# 54.14             wait
# 53.61             wait
# 53.08             wait
# 52.55             wait
# 52.03             wait
# 51.52             wait
# 51.00             wait
# 50.50             wait
# 50.00             wait
# 49.50             wait
# 49.00             wait
# 48.51             wait
# 48.03             wait
# 47.55         exercise
# 47.07         exercise
# 46.60         exercise
# 46.14         exercise
# 45.68         exercise
# 45.22         exercise
# 44.77         exercise
# 44.32         exercise
# 43.88         exercise
# 43.44         exercise

# %%
# Starts at day 1 with initial stock price 50
# value_iteration(0, 50)

# %%
# import pandas as pd
# #Parameters
# N = 5 # Total day
# chance_up = 0.6 # Chance of going up
# chance_down = 0.4 # Chance of going down
# percentage_up = 0.01 # Percentage of going up
# percentage_down = 0.01 # Percentage of going down

# action = ["" for d in range(N)] # Initialize action array
# value = [0 for d in range(N)] # Initialize value array
# wait = [0 for d in range(N)]
# exercise = [0 for d in range(N)]
# optimal_value = [0 for d in range(N)]

# def value_iteration(day, price):
    
#     # Calcululate the price of exercise
#     if (price >= 48):
#         exercise_value = 0
#     else:
#         exercise_value = 48 - price
    
#     # Calculate the price of wait
#     if day < N-1:
#         wait_value = chance_up * value_iteration(day + 1, 1.01*price) + chance_down * value_iteration(day + 1, 0.99*price)
#         wait[day] = wait_value
#         exercise[day] = exercise_value
        
#         # Decides the optimal action
#         if (wait_value > exercise_value):
#             action[day] = "wait"
#             optimal_value[day] = wait_value
#         else:
#             action[day] = "exercise"
#             optimal_value[day] = exercise_value
    
#     # The last day
#     if day == N-1:
#         action[day] = "exercise"
#         wait[day] = 0
#         exercise[day] = exercise_value
#         optimal_value[day] = exercise_value
        
#     return optimal_value[day]
